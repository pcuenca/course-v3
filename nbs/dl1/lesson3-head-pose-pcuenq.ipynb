# %% [markdown]
# ## Regression with BIWI head pose dataset

# %% [markdown]
# This is a more advanced example to show how to create custom datasets and do regression with images. Our task is to find the center of the head in each image. The data comes from the [BIWI head pose dataset](https://data.vision.ee.ethz.ch/cvl/gfanelli/head_pose/head_forest.html#db), thanks to Gabriele Fanelli et al. We have converted the images to jpeg format, so you should download the converted dataset from [this link](https://s3.amazonaws.com/fast-ai-imagelocal/biwi_head_pose.tgz).

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# ## Getting and converting the data

# %%
path = untar_data(URLs.BIWI_HEAD_POSE)

# %%
cal = np.genfromtxt(path/'01'/'rgb.cal', skip_footer=6); cal
# Out:
# array([[517.679,   0.   , 320.   ],
#        [  0.   , 517.679, 240.5  ],
#        [  0.   ,   0.   ,   1.   ]])

# %%
fname = '09/frame_00667_rgb.jpg'

# %%
def img2txt_name(f): return path/f'{str(f)[:-7]}pose.txt'

# %%
img = open_image(path/fname)
img.show()

# %%
ctr = np.genfromtxt(img2txt_name(fname), skip_header=3); ctr
# Out:
# array([187.332 ,  40.3892, 893.135 ])

# %%
def convert_biwi(coords):
    c1 = coords[0] * cal[0][0]/coords[2] + cal[0][2]
    c2 = coords[1] * cal[1][1]/coords[2] + cal[1][2]
    return tensor([c2,c1])

def get_ctr(f):
    ctr = np.genfromtxt(img2txt_name(f), skip_header=3)
    return convert_biwi(ctr)

def get_ip(img,pts): return ImagePoints(FlowField(img.size, pts), scale=True)

# %%
help(ImagePoints)
# Out:
# Help on class ImagePoints in module fastai.vision.image:
#
# class ImagePoints(Image)
#  |  ImagePoints(flow: fastai.vision.image.FlowField, scale: bool = True, y_first: bool = True)
#  |
#  |  Support applying transforms to a `flow` of points.
#  |
#  |  Method resolution order:
#  |      ImagePoints
#  |      Image
#  |      fastai.core.ItemBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, flow: fastai.vision.image.FlowField, scale: bool = True, y_first: bool = True)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  clone(self)
#  |      Mimic the behavior of torch.clone for `ImagePoints` objects.
#  |
#  |  coord(self, func: Callable[[fastai.vision.image.FlowField, Collection[Any], Dict[str, Any]], torch.Tensor], *args, **kwargs) -> 'ImagePoints'
#  |      Put `func` with `args` and `kwargs` in `self.flow_func` for later.
#  |
#  |  lighting(self, func: Callable[[torch.Tensor, Collection[Any], Dict[str, Any]], torch.Tensor], *args: Any, **kwargs: Any) -> 'ImagePoints'
#  |      Equivalent to `image = sigmoid(func(logit(image)))`.
#  |
#  |  pixel(self, func: Callable[[torch.Tensor, Collection[Any], Dict[str, Any]], torch.Tensor], *args, **kwargs) -> 'ImagePoints'
#  |      Equivalent to `self = func_flow(self)`.
#  |
#  |  reconstruct(self, t, x)
#  |
#  |  refresh(self) -> 'ImagePoints'
#  |      Apply any logit, flow, or affine transfers that have been sent to the `Image`.
#  |
#  |  resize(self, size: Union[int, Tuple[int, int, int]]) -> 'ImagePoints'
#  |      Resize the image to `size`, size can be a single int.
#  |
#  |  show(self, ax: matplotlib.axes._axes.Axes = None, figsize: tuple = (3, 3), title: Union[str, NoneType] = None, hide_axis: bool = True, **kwargs)
#  |      Show the `ImagePoints` on `ax`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  data
#  |      Return the points associated to this object.
#  |
#  |  device
#  |
#  |  flow
#  |      Access the flow-field grid after applying queued affine and coord transforms.
#  |
#  |  shape
#  |
#  |  size
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Image:
#  |
#  |  affine(self, func: Callable[[Dict[str, Any]], torch.Tensor], *args, **kwargs) -> 'Image'
#  |      Equivalent to `image.affine_mat = image.affine_mat @ func()`.
#  |
#  |  apply_tfms(self, tfms: Union[Callable, Collection[Callable]], do_resolve: bool = True, xtra: Union[Dict[Callable, dict], NoneType] = None, size: Union[int, Tuple[int, int, int], NoneType] = None, resize_method: fastai.vision.image.ResizeMethod = None, mult: int = None, padding_mode: str = 'reflection', mode: str = 'bilinear', remove_out: bool = True) -> torch.Tensor
#  |      Apply all `tfms` to the `Image`, if `do_resolve` picks value for random args.
#  |
#  |  brightness lambda x, *args, **kwargs
#  |
#  |  contrast lambda x, *args, **kwargs
#  |
#  |  crop lambda x, *args, **kwargs
#  |
#  |  crop_pad lambda x, *args, **kwargs
#  |
#  |  cutout lambda x, *args, **kwargs
#  |
#  |  dihedral lambda x, *args, **kwargs
#  |
#  |  dihedral_affine lambda x, *args, **kwargs
#  |
#  |  flip_affine lambda x, *args, **kwargs
#  |
#  |  flip_lr lambda x, *args, **kwargs
#  |
#  |  jitter lambda x, *args, **kwargs
#  |
#  |  pad lambda x, *args, **kwargs
#  |
#  |  perspective_warp lambda x, *args, **kwargs
#  |
#  |  rotate lambda x, *args, **kwargs
#  |
#  |  save(self, fn: Union[pathlib.Path, str])
#  |      Save the image to `fn`.
#  |
#  |  set_sample(self, **kwargs) -> 'ImageBase'
#  |      Set parameters that control how we `grid_sample` the image after transforms are applied.
#  |
#  |  skew lambda x, *args, **kwargs
#  |
#  |  squish lambda x, *args, **kwargs
#  |
#  |  symmetric_warp lambda x, *args, **kwargs
#  |
#  |  tilt lambda x, *args, **kwargs
#  |
#  |  zoom lambda x, *args, **kwargs
#  |
#  |  zoom_squish lambda x, *args, **kwargs
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Image:
#  |
#  |  affine_mat
#  |      Get the affine matrix that will be applied by `refresh`.
#  |
#  |  logit_px
#  |      Get logit(image.px).
#  |
#  |  px
#  |      Get the tensor pixel buffer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fastai.core.ItemBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
get_ctr(fname)
# Out:
# tensor([263.9104, 428.5814])

# %%
ctr = get_ctr(fname)
img.show(y=get_ip(img, ctr), figsize=(6, 6))

# %% [markdown]
# ## Creating a dataset

# %%
data = (PointsItemList.from_folder(path)
        .split_by_valid_func(lambda o: o.parent.name=='13')
        .label_from_func(get_ctr)
        .transform(get_transforms(), tfm_y=True, size=(120,160))
        .databunch().normalize(imagenet_stats)
       )

# %%
data.show_batch(3, figsize=(9,6))

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.75E-02

# %%
lr = 2e-2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='237', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-be1ab4476b35> in <module>
# ----> 1 learn.fit_one_cycle(5, slice(lr))
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start, tot_epochs=tot_epochs,
#      21                                        start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      78
#      79         try:
# ---> 80             return func(*args, **kwargs)
#      81         except Exception as e:
#      82             if ("CUDA out of memory" in str(e) or
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      86             cb_handler.set_dl(data.train_dl)
#      87             cb_handler.on_epoch_begin()
# ---> 88             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      89                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#      90                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         self.update(0)
#      65         try:
# ---> 66             for i,o in enumerate(self._gen):
#      67                 yield o
#      68                 if self.auto_update: self.update(i+1)
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     629         while True:
#     630             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 631             idx, batch = self._get_batch()
#     632             self.batches_outstanding -= 1
#     633             if idx != self.rcvd_idx:
#
# ~/code/fast.ai/env/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     608             # need to call `.task_done()` because we don't use `.join()`.
#     609         else:
# --> 610             return self.data_queue.get()
#     611
#     612     def __next__(self):
#
# /usr/local/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# /usr/local/lib/python3.7/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /usr/local/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /usr/local/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results()

# %% [markdown]
# ## Data augmentation

# %%
tfms = get_transforms(max_rotate=20, max_zoom=1.5, max_lighting=0.5, max_warp=0.4, p_affine=1., p_lighting=1.)

data = (PointsItemList.from_folder(path)
        .split_by_valid_func(lambda o: o.parent.name=='13')
        .label_from_func(get_ctr)
        .transform(get_transforms(), tfm_y=True, size=(120,160))
        .databunch().normalize(imagenet_stats)
       )

# %%
def _plot(i,j,ax):
    x,y = data.train_ds[0]
    x.show(ax, y=y)

plot_multi(_plot, 3, 3, figsize=(8,6))
